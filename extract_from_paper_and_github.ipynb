# %% [markdown]
# # Exploring a paper + repository
# https://elifesciences.org/articles/67509 (PMED: 34409937)

# %%
import re
import os
import mimetypes
import tempfile
import subprocess

from skimage.metrics import structural_similarity as ssim
import requests
import markdown
import lxml.html
import pdf2image
from PIL import Image
import numpy as np

# %%
PAPER_URL = 'https://api.elifesciences.org/articles/67509'
response = requests.get(PAPER_URL)
article = response.json()['body']

# %%
def find_github_repo(blocks):
    # TODO: assumes only a single repository in the text
    for block in blocks:
        if block['type'] == 'paragraph':
            text = block['text']
            match = re.search(r'https:\/\/github.com\/([a-zA-Z0-9-]+)\/([a-zA-Z0-9_\-]+)\b', text)  # TODO: Only matches main repo, not branches, etc.
            if match:
                return match.group(1), match.group(2)
        elif block['type'] == 'section':
            result = find_github_repo(block['content'])
            if result:
                return result
        else:  # figure, etc.
            continue

user, repo = find_github_repo(article)

# Get the filenames from the github repo (no longer necessary, we clone the repo anyway)
def get_repo_filenames(user, repo):
    response = requests.get(f'https://api.github.com/repos/{user}/{repo}/git/trees/master?recursive=1')
    tree = response.json()['tree']
    dirnames = [t['path'] for t in tree if t['type'] == 'tree']
    filenames = [(os.path.dirname(t['path']), os.path.basename(t['path']))
                 for t in tree if t['type'] == 'blob']
    return dirnames, filenames

# %%
tmp_dir = tempfile.mkdtemp()
subprocess.run(['git', 'clone', '--depth', '1', f'https://github.com/{user}/{repo}'], cwd=tmp_dir)
# Out:
# CompletedProcess(args=['git', 'clone', '--depth', '1', 'https://github.com/vsbuffalo/paradox_variation'], returncode=0)

# %%
def calc_hash(filename):  # (no longer used, not working well)
    if filename.endswith('.pdf'):
        try:
            images = pdf2image.convert_from_path(filename)
        except Exception:
            print('PDF conversion failed for file', filename)
            return None
        if len(images) != 1:  # not a single page, maybe a paper?
            return None
        image = images[0]
    else:
        try:
            image = Image.open(filename)
        except Exception:
            print('Cannot calculate hash for file', filename)  # e.g. svg files
            return None
    return str(imagehash.average_hash(image, hash_size=16)) + str(imagehash.colorhash(image))

def get_image(filename):
    if filename.endswith('.pdf'):
        try:
            images = pdf2image.convert_from_path(filename)
        except Exception:
            print('PDF conversion failed for file', filename)
            return None
        if len(images) != 1:  # not a single page, maybe a paper?
            return None
        image = images[0]
    else:
        try:
            image = Image.open(filename)
        except Exception:
            print('Cannot open file', filename)  # e.g. svg files
            return None
    return image

# %%
manifest = {}  # The main data structure storing all the information about our files

base_path = os.path.join(tmp_dir, repo)
for root, dirs, files in os.walk(base_path):
    dirname = root[len(base_path)+1:]  # quick&dirty way to only retain the path in the repo
    for fname in files:
        if '.git' in dirname:
            continue
        fullname = os.path.join(root, fname)
        mime_type, _ = mimetypes.guess_type(fname, strict=False)
        manifest[os.path.join(dirname, fname)] = {'type': mime_type, 'references': []}

# %% [markdown]
# The filenames in the repository are the basic unit that we'll display in a graph. In the following, the main data structure is a dictionary, the "manifest", with the filename as the key, and a dictionary with additional information as the value. The information dictionary currently has the following information:
#
# * `inputs`: list of files that go into this file (e.g. loaded csv files)
# * `outputs`: list of files that are produced by this file (e.g. saved figures)
# * `dependencies`: other source files used by this file (e.g. via import)
# * `type`: the mime type of the file
# * `references`: list of references to this file (textual references, not inputs/outputs/dependencies)
#
# Each reference is given as a dictionary. Currently two types of references are provided, references in README files, and references in the publication. Each reference has two entries:
# * `origin`: the name of the README file or a link to the article
# * `context`: the surrounding text of the reference
# * `section`: the section of the document where the reference is

# %% [markdown]
# ## Extracting information from the elife article
#
# The text might refer to specific files, and some of the figures in the paper might be present in the repository.

# %%
# Find references to filenames and compare figures in elife articles

# Simple tag remover
TAG_RE = re.compile(r'<[^>]+>')
fig_dir = tempfile.mkdtemp()

def find_references_elife(blocks, manifest, path=None):
    if path is None:
        path = []
    for block in blocks:
        if block['type'] == 'paragraph':
            continue
            text = TAG_RE.sub('', block['text'])
            for filename in manifest:
                basename = os.path.basename(filename)
                if '.' not in basename:  # skip too generic filenames like "description"
                    continue
                if basename in text:
                    manifest[filename]['references'].append({'origin': PAPER_URL,
                                                             'context': text,
                                                             'section': ' → '.join(path)})
        elif block['type'] == 'figure':
            for image_block in block['assets']:
                if not 'image' in image_block:
                    continue
                source_file = os.path.join(fig_dir, image_block['image']['source']['filename'])
                if not os.path.exists(source_file):
                    # Download the source image
                    response = requests.get(image_block['image']['source']['uri'], allow_redirects=True)
                    with open(source_file, 'wb') as f:
                        f.write(response.content)
                source_image = get_image(source_file)
                if source_image is None:
                    continue
                print(f'Comparing {source_file} to images in the repo')
                # Compare to all known images
                for repo_file, metadata in manifest.items():
                    if not 'notebooks/figures' in repo_file:
                        continue
                    if (metadata['type'] is None
                            or not (metadata['type'] == 'application/pdf' or metadata['type'].startswith('image/'))):
                        continue
                    repo_image = get_image(os.path.join(tmp_dir, repo, repo_file))
                    if repo_image is None:
                        continue
                    if repo_image.size != source_image.size:
                        repo_aspect = repo_image.size[0]/repo_image.size[1]
                        source_aspect = source_image.size[0]/source_image.size[1]
                        if abs(repo_aspect - source_aspect) > 0.01:
                            continue
                        if repo_image.size[0] < source_image.size[0]:  # scale to repo_image size
                            scaled_repo_image = repo_image
                            scaled_source_image = source_image.resize(repo_image.size)
                        else:  # scale to source image size
                            scaled_repo_image = repo_image.resize(source_image.size)
                            scaled_source_image = source_image
                    else:
                        # No scaling necessary
                        scaled_repo_image = repo_image
                        scaled_source_image = source_image
                    
                    # Compare with structural similary
                    similarity = ssim(np.asarray(scaled_repo_image), np.asarray(scaled_source_image),
                                      multichannel=True)
                    if similarity > 0.9:
                        print(f"Found a match {repo_file} == {image_block['label']}!", repo_file)
                        metadata['references'].append({'origin': PAPER_URL,
                                                       'context': image_block['title'],
                                                       'label': image_block['label']})
                            
        elif block['type'] == 'section':
            find_references_elife(block['content'], manifest, path=path + [block['title']])
        else:
            print('Unknown block type', block['type'])
            continue

# %%
find_references_elife(article, manifest)
# Out:
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-v3.jpg to images in the repo
# Found a match notebooks/figures/Nc_figure.pdf == Figure 1! notebooks/figures/Nc_figure.pdf
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-figsupp1-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-figsupp2-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-figsupp3-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-figsupp4-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig1-figsupp5-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig2-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig2-figsupp1-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig2-figsupp2-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig2-figsupp3-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig2-figsupp4-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig3-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Found a match notebooks/figures/diversity_pcm.pdf == Figure 3! notebooks/figures/diversity_pcm.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig3-figsupp1-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig3-figsupp2-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig3-figsupp3-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Unknown block type mathml
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-figsupp1-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-figsupp2-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-figsupp3-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-figsupp4-v3.jpg to images in the repo
# Found a match notebooks/figures/corbett_detig.pdf == Figure 4—figure supplement 4! notebooks/figures/corbett_detig.pdf
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf
# Comparing /tmp/tmp8bidx57x/elife-67509-fig4-figsupp5-v3.jpg to images in the repo
# PDF conversion failed for file /tmp/tmpu20l61i5/paradox_variation/notebooks/figures/Rplots.pdf

# %% [markdown]
# ## Extracting crosslinks in the repo
#
# * README files might refer to specific filenames
# * scripts might load some data, write some data, and import/reuse other scripts

# %%
# Find relevant notes in README files
readmes = [fname for fname in manifest 
          if os.path.basename(fname).lower() in ['readme', 'readme.md', 'readme.txt']]
readmes
# Out:
# ['README.md', 'data/README.md', 'data/range_maps/README.md']

# %%
def _find_filename_in_tree(tree, filename):
    for el in tree.iter():
        if el.text is not None and filename in el.text:
            return el
        if el.tail is not None and filename in el.tail:
            return el

def _get_context_paragraph(tree):
    if tree.tag in ('p', 'li') or tree.getparent() is None:
        return tree.text_content()
    else:
        return _get_context_paragraph(tree.getparent())

def _get_headers(tree, headers=None):
    if headers is None:
        headers = []
    if tree.tag in ('h1', 'h2', 'h3', 'h4'):  #FIXME...
        headers.append(tree.text_content())
    if tree.getprevious() is not None:
        return _get_headers(tree.getprevious(), headers=headers)
    elif tree.getparent() is not None:
        return _get_headers(tree.getparent(), headers=headers)
    else:
        return headers
        
    
def find_filename_in_html(text, filename):
    parsed = lxml.html.fromstring(html_text)
    found = _find_filename_in_tree(parsed, filename)
    assert found is not None
    # Get context paragraph and possible headers
    paragraph = _get_context_paragraph(found)
    headers = ' → '.join(reversed(_get_headers(found)))
    return paragraph, headers
    
    
for readme in readmes:
    readme_text = open(os.path.join(tmp_dir, repo, readme)).read()
    for filename, metadata in manifest.items():
        if not '.' in filename or filename in readmes:
            continue
        if filename in readme_text:
            if readme.endswith('.md'):
                html_text = markdown.markdown(readme_text)
                par, headers = find_filename_in_html(html_text, filename)
                metadata['references'].append({'origin': readme,
                                               'context': par,
                                               'section': headers})
            else:
                description = re.search(f"""["'`]?{filename}["'`]??(:| is| contains)?(.*\n)""", readme_text)
                if description:
                    metadata['references'].append({'origin': readme,
                                                   'context': description.group(0)})
                else:
                    description = re.search(f"""?([\n^]).*{filename}.*?([\n$])""", readme_text)
                    if description:
                        metadata['references'].append({'origin': readme,
                                                   'context': description.group(0)})
                    else:
                        metadata['references'].append({'origin': readme})

# %%
def input_output_r(content):
    # FIXME: more robust parsing
    inputs = re.findall("""read_[ct]sv\(['"]([\.\/\-_0-9a-zA-Z]+)['"][^)]*\)""", content)
    inputs.extend(re.findall("""load\(['"]([\.\/\-_0-9a-zA-Z]+)['"]\)""", content))
    outputs = re.findall("""write_[ct]sv\([^,]+,\s*['"]([\.\/\-_0-9a-zA-Z]+)['"][^)]*\)""", content)
    outputs.extend(re.findall("""pdf\(['"]([\.\/\-_0-9a-zA-Z]+)['"][^)]*\)""", content))
    outputs.extend(re.findall("""save\(.*, file=['"]([\.\/\-_0-9a-zA-Z]+)['"][^)]*\)""", content))
    dependencies = re.findall("""source\(['"]([\.\/\-_0-9a-zA-Z]+)['"]\)""", content)
    return set(inputs), set(outputs), set(dependencies)

# %%
def normalize_paths(filenames, reference_name):
    reference_dir = os.path.dirname(reference_name)
    return {os.path.normpath(os.path.join(reference_dir, fname))
            for fname in filenames}

# %%
for filename, metadata in manifest.items():
    if not filename.endswith('.r'):
        continue
        
    with open(os.path.join(tmp_dir, repo, filename), 'r') as f:
        lines = f.readlines()
        cleaned_lines = [l for l in lines if not l.strip().startswith('#')]
        content = '\n'.join(cleaned_lines)
        inputs, outputs, dependencies = input_output_r(content)
        metadata['inputs'] = normalize_paths(inputs, filename)
        metadata['outputs'] = normalize_paths(outputs, filename)
        metadata['dependencies'] = normalize_paths(dependencies, filename)

# %%
import pprint
pprint.pprint(manifest)
# Out:
# {'R/node_height.r': {'dependencies': set(),
#                      'inputs': set(),
#                      'outputs': set(),
#                      'references': [],
#                      'type': None},
#  'R/range_funcs.r': {'dependencies': set(),
#                      'inputs': set(),
#                      'outputs': set(),
#                      'references': [],
#                      'type': None},
#  'R/utilities.r': {'dependencies': set(),
#                    'inputs': set(),
#                    'outputs': set(),
#                    'references': [],
#                    'type': None},
#  'README.md': {'references': [], 'type': 'text/markdown'},
#  'data/Dataset_S1.txt': {'references': [], 'type': 'text/plain'},
#  'data/Makefile': {'references': [], 'type': None},
#  'data/RAW_dataset_Jan_06_2012.xlsx': {'references': [{'context': 'RAW_dataset_Jan_06_2012.xls: '
#                                                                   'this was '
#                                                                   'downloaded '
#                                                                   'from the '
#                                                                   'WayBack '
#                                                                   "Machine's\n"
#                                                                   '  archive '
#                                                                   'of\n'
#                                                                   '  '
#                                                                   'https://web.archive.org/web/20170710053101/http://www.drosophila-speciation-patterns.com/data/RAW_dataset_Jan_06_2012.xlsx',
#                                                        'origin': 'data/README.md',
#                                                        'section': 'Data files '
#                                                                   '→ My Size '
#                                                                   'Data → '
#                                                                   'Drosophila '
#                                                                   'Range '
#                                                                   'Data'}],
#                                        'type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'},
#  'data/README.md': {'references': [], 'type': 'text/markdown'},
#  'data/S2_Data.xls': {'references': [], 'type': 'application/vnd.ms-excel'},
#  'data/anage_data.r': {'dependencies': set(),
#                        'inputs': {'data/anage_data.tsv'},
#                        'outputs': set(),
#                        'references': [],
#                        'type': None},
#  'data/anage_data.tsv': {'references': [], 'type': 'text/tab-separated-values'},
#  'data/anage_data_updated.tsv': {'references': [],
#                                  'type': 'text/tab-separated-values'},
#  'data/biconmap.pdf': {'references': [], 'type': 'application/pdf'},
#  'data/biomass.tsv': {'references': [], 'type': 'text/tab-separated-values'},
#  'data/body_size_fecundity.Rdata': {'references': [], 'type': None},
#  'data/body_size_map_length.Rdata': {'references': [], 'type': None},
#  'data/combined_data.tsv': {'references': [],
#                             'type': 'text/tab-separated-values'},
#  'data/combined_dataset.r': {'dependencies': {'R/utilities.r',
#                                               'data/popsize_models.r',
#                                               'data/taxonomy_fixes.r'},
#                              'inputs': {'data/corbett_detig_2015_updated.tsv',
#                                         'data/damuth1987.tsv',
#                                         'data/gbif_ranges.tsv',
#                                         'data/leffler_et_al_2012_updated.tsv',
#                                         'data/romiguier_et_al_2014_updated.tsv',
#                                         'data/stapley_et_al_2017_updated.tsv'},
#                              'outputs': {'data/calibrated_phylogeny.Rdata',
#                                          'data/combined_data.tsv',
#                                          'data/redlist_popsizes.tsv',
#                                          'data/size_mass_density_lms.Rdata'},
#                              'references': [],
#                              'type': None},
#  'data/combined_dataset_hier.Rdata': {'references': [], 'type': None},
#  'data/combined_dataset_otl.Rdata': {'references': [], 'type': None},
#  'data/combined_tree.Rdata': {'references': [], 'type': None},
#  'data/corbett_detig_2015_data.r': {'dependencies': set(),
#                                     'inputs': set(),
#                                     'outputs': set(),
#                                     'references': [],
#                                     'type': None},
#  'data/corbett_detig_2015_updated.tsv': {'references': [],
#                                          'type': 'text/tab-separated-values'},
#  'data/damuth1987.pdf': {'references': [], 'type': 'application/pdf'},
#  'data/damuth1987.tsv': {'references': [], 'type': 'text/tab-separated-values'},
#  'data/damuth1987.xlsx': {'references': [],
#                           'type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'},
#  'data/datelife.Rdata': {'references': [], 'type': None},
#  'data/dmel/Makefile': {'references': [], 'type': None},
#  'data/dmel/annotation.r': {'dependencies': set(),
#                             'inputs': set(),
#                             'outputs': {'data/dmel/dmel_annotation_summary.tsv',
#                                         'data/dmel/dmel_seqlens.tsv'},
#                             'references': [],
#                             'type': None},
#  'data/dmel/dmel_annotation_summary.tsv': {'references': [],
#                                            'type': 'text/tab-separated-values'},
#  'data/dmel/dmel_seqlens.tsv': {'references': [],
#                                 'type': 'text/tab-separated-values'},
#  'data/journal.pbio.1002112.s016.XLS': {'references': [],
#                                         'type': 'application/vnd.ms-excel'},
#  'data/journal.pbio.1002112.s017.XLS': {'references': [],
#                                         'type': 'application/vnd.ms-excel'},
#  'data/journal.pbio.1002112.s018.XLS': {'references': [],
#                                         'type': 'application/vnd.ms-excel'},
#  'data/leffler_et_al_2012.tsv': {'references': [],
#                                  'type': 'text/tab-separated-values'},
#  'data/leffler_et_al_2012_ave_updated.tsv': {'references': [],
#                                              'type': 'text/tab-separated-values'},
#  'data/leffler_et_al_2012_data.r': {'dependencies': {'R/utilities.r'},
#                                     'inputs': {'data/leffler_et_al_2012.tsv'},
#                                     'outputs': {'data/leffler_et_al_2012_updated.tsv'},
#                                     'references': [],
#                                     'type': None},
#  'data/leffler_et_al_2012_hier.Rdata': {'references': [], 'type': None},
#  'data/leffler_et_al_2012_updated.Rdata': {'references': [], 'type': None},
#  'data/leffler_et_al_2012_updated.tsv': {'references': [],
#                                          'type': 'text/tab-separated-values'},
#  'data/leffler_occ.Rdata': {'references': [], 'type': None},
#  'data/palstra_fraser_2012.Rmd': {'references': [], 'type': None},
#  'data/palstra_fraser_2012_fig2_fig3_data.tsv': {'references': [],
#                                                  'type': 'text/tab-separated-values'},
#  'data/popsize_models.r': {'dependencies': set(),
#                            'inputs': {'data/combined_data.tsv',
#                                       'data/damuth1987.tsv'},
#                            'outputs': {'data/post_pred_draws.Rdata'},
#                            'references': [],
#                            'type': None},
#  'data/range_maps/1-Worldwide-distribution-of-the-Pacific-oyster-Crassostrea-gigas.png': {'references': [],
#                                                                                           'type': 'image/png'},
#  'data/range_maps/CL-35_Pinus_massoniana_range_map.png': {'references': [],
#                                                           'type': 'image/png'},
#  'data/range_maps/Callithrix_jacchus_distribution.svg': {'references': [],
#                                                          'type': 'image/svg+xml'},
#  'data/range_maps/File:Pinus_balfouriana_range_map_1.png': {'references': [],
#                                                             'type': 'image/png'},
#  'data/range_maps/Geographic-distribution-of-Reticulitermes-species-Isoptera-Rhinotermitidae-in-western.png': {'references': [],
#                                                                                                                'type': 'image/png'},
#  'data/range_maps/Grivet_area.png': {'references': [], 'type': 'image/png'},
#  'data/range_maps/Mapa_distribuicao_pongo_pygmaeus.png': {'references': [],
#                                                           'type': 'image/png'},
#  'data/range_maps/Pinus_pinaster_range.svg': {'references': [],
#                                               'type': 'image/svg+xml'},
#  'data/range_maps/README.md': {'references': [], 'type': 'text/markdown'},
#  'data/range_maps/argopecten-irradians.png': {'references': [],
#                                               'type': 'image/png'},
#  'data/range_maps/canis_lupus_range_iucn.png': {'references': [],
#                                                 'type': 'image/png'},
#  'data/range_maps/ciona_intestinalis.jpg': {'references': [],
#                                             'type': 'image/jpeg'},
#  'data/range_maps/cystodytes_dellechiajei.jpg': {'references': [],
#                                                  'type': 'image/jpeg'},
#  'data/range_maps/drosophila_range_map.jpg': {'references': [],
#                                               'type': 'image/jpeg'},
#  'data/range_maps/hippocampus_kuda.jpg': {'references': [],
#                                           'type': 'image/jpeg'},
#  'data/range_maps/shrimp_ranges.png': {'references': [], 'type': 'image/png'},
#  'data/redlist.Rdata': {'references': [], 'type': None},
#  'data/redlist_popsizes.tsv': {'references': [],
#                                'type': 'text/tab-separated-values'},
#  'data/romiguier_et_al_2014_data.r': {'dependencies': set(),
#                                       'inputs': set(),
#                                       'outputs': {'data/romiguier_et_al_2014_updated.tsv'},
#                                       'references': [],
#                                       'type': None},
#  'data/romiguier_et_al_2014_supptable_2.xls': {'references': [],
#                                                'type': 'application/vnd.ms-excel'},
#  'data/romiguier_et_al_2014_updated.tsv': {'references': [],
#                                            'type': 'text/tab-separated-values'},
#  'data/romiguier_et_al_supptable_3.pdf': {'references': [],
#                                           'type': 'application/pdf'},
#  'data/romiguier_et_al_supptable_3_bodymass.csv': {'references': [],
#                                                    'type': 'text/csv'},
#  'data/romiguier_et_al_supptable_3_bodysize.csv': {'references': [],
#                                                    'type': 'text/csv'},
#  'data/romiguier_et_al_supptable_3_fecundity.csv': {'references': [],
#                                                     'type': 'text/csv'},
#  'data/romiguier_et_al_supptable_3_longevity.csv': {'references': [],
#                                                     'type': 'text/csv'},
#  'data/romiguier_et_al_supptable_3_propagule.csv': {'references': [],
#                                                     'type': 'text/csv'},
#  'data/shapiro_et_al_2007.tsv': {'references': [],
#                                  'type': 'text/tab-separated-values'},
#  'data/species_by_class.tsv': {'references': [],
#                                'type': 'text/tab-separated-values'},
#  'data/species_notes.txt': {'references': [], 'type': 'text/plain'},
#  'data/species_range_fixes.r': {'dependencies': set(),
#                                 'inputs': set(),
#                                 'outputs': set(),
#                                 'references': [],
#                                 'type': None},
#  'data/species_ranges.r': {'dependencies': {'R/range_funcs.r',
#                                             'data/species_range_fixes.r'},
#                            'inputs': {'data/leffler_et_al_2012_updated.tsv',
#                                       'data/romiguier_et_al_2014_updated.tsv',
#                                       'data/stapley_et_al_2017_updated.tsv'},
#                            'outputs': {'data/gbif_ranges.tsv'},
#                            'references': [],
#                            'type': None},
#  'data/stapley_et_al_2017.Rdata': {'references': [], 'type': None},
#  'data/stapley_et_al_2017.csv': {'references': [], 'type': 'text/csv'},
#  'data/stapley_et_al_2017.xlsx': {'references': [],
#                                   'type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'},
#  'data/stapley_et_al_2017_data.r': {'dependencies': {'R/utilities.r'},
#                                     'inputs': {'data/stapley_et_al_2017.csv'},
#                                     'outputs': {'data/stapley_et_al_2017_updated.tsv'},
#                                     'references': [],
#                                     'type': None},
#  'data/stapley_et_al_2017_data_hier.Rdata': {'references': [], 'type': None},
#  'data/stapley_et_al_2017_otl.Rdata': {'references': [], 'type': None},
#  'data/stapley_et_al_2017_updated.tsv': {'references': [],
#                                          'type': 'text/tab-separated-values'},
#  'data/sweep_param_ests.tsv': {'references': [],
#                                'type': 'text/tab-separated-values'},
#  'data/taxonomy_fixes.r': {'dependencies': set(),
#                            'inputs': set(),
#                            'outputs': set(),
#                            'references': [],
#                            'type': None},
#  'data/total_range_plots/Abatus_agassizi.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Abatus_cordatus.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Acacia_mangium.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Acromyrmex_echinatior.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Acropora_millepora.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Actinidia_chinensis.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Acyrthosiphon_pisum.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Aedes_aegypti.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Aedes_albopictus.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Aegilops_sharonensis.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Aegilops_tauschii.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Aegilops_umbellulata.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Agaricus_bisporus.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Agelaius_phoeniceus.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Agrostis_capillaris.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Agrostis_stolonifera.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Ailuropoda_melanoleuca.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Allium_cepa.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Allolobophora_chlorotica.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Amaranthus_hybridus.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Ambystoma_tigrinum.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Amphimedon_queenslandica.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Ananas_comosus.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Anas_platyrhynchos.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Anguilla_japonica.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_arabiensis.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_baimaii.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_cruzii.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_dirus.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_funestus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_gambiae.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_melas.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_merus.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_quadriannulatus.pdf': {'references': [],
#                                                           'type': 'application/pdf'},
#  'data/total_range_plots/Anopheles_scanloni.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Anoplopoma_fimbria.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Aphanarthrum_glabrum.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Aphanarthrum_subglabrum.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Apis_cerana.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Apis_mellifera.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Aporrectodea_icterica.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Apostichopus_japonicus.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Aptenodytes_patagonicus.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Aquila_clanga.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Aquila_pomarina.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Aquilegia_formosa.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Aquilegia_pubescens.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Arabidopsis_halleri.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Arabidopsis_lyrata.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Arabidopsis_thaliana.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Arachis_duranensis.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Arachis_hypogaea.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Argopecten_irradians.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Aristichthys_nobilis.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Armadillidium_nasatum.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Armadillidium_vulgare.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Artemia_franciscana.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Artemia_salina.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Artemia_sinica.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Ascochyta_rabiei.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Aspergillus_nidulans.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Astatotilapia_burtoni.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Astyanax_mexicanus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Avena_sativa.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'data/total_range_plots/Bactrocera_cucurbitae.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Bactrocera_depressa.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Balaenoptera_bonaerensis.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Barbarea_vulgaris.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Begonia_plebeja.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Beta_vulgaris.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Betula_pendula.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Bicyclus_anynana.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Bison_bison.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Biston_betularia.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Boechera_stricta.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Boehmeria_nivea.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Bombus_terrestris.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Bombyx_mori.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Bos_taurus.pdf': {'references': [],
#                                            'type': 'application/pdf'},
#  'data/total_range_plots/Bostrycapulus_aculeatus.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Bracon_hebetor.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_campestris.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_carinata.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_juncea.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_napus.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_oleracea.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Brassica_rapa.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Caenorhabditis_brenneri.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Caenorhabditis_briggsae.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Caenorhabditis_elegans.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Caenorhabditis_remanei.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Cajanus_cajan.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Callithrix_jacchus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Camelina_sativa.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Camellia_sinensis.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Camponotus_aethiops.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Camponotus_ligniperdus.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Canis_latrans.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Canis_lupus.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Capra_hircus.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'data/total_range_plots/Capsella_bursa-pastoris.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Capsella_grandiflora.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Capsella_rubella.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Capsicum_annuum.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Capsicum_baccatum.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Carassius_auratus.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Carcinus_aestuarii.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Carica_papaya.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Carthamus_tinctorius.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Castanea_mollissima.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Catharanthus_roseus.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Cecidostiba_fungosa.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Ceratitis_capitata.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Ceratopteris_richardii.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Chelonoidis_nigra.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Chenopodium_quinoa.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Chimonanthus_praecox.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Chlamydomonas_reinhardtii.pdf': {'references': [],
#                                                           'type': 'application/pdf'},
#  'data/total_range_plots/Chlamys_farreri.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Chlorocebus_aethiops.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Cicer_arietinum.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Cichla_pleiozona.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Ciona_intestinalis.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Ciona_roulei.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'data/total_range_plots/Ciona_savignyi.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Citrullus_lanatus.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Citrus_clementina.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Citrus_sinensis.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Clunio_marinus.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Cocos_nucifera.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Coffea_arabica.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Coprinus_cinereus.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Corchorus_capsularis.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Corchorus_olitorius.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Coregonus_clupeaformis.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Cornus_florida.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Coturnix_japonica.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Crassostrea_gigas.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Crassostrea_virginica.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Crepidula_fornicata.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Crepidula_plana.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Crocodylus_porosus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Cryptococcus_neoformans.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Cryptomeria_japonica.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Ctenopharyngodon_idella.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Cucumis_melo.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'data/total_range_plots/Cucumis_sativus.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Cucurbita_maxima.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Cucurbita_moschata.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Cucurbita_pepo.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Culex_hortensis.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Culex_pipiens.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Culex_torrentium.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Cyanistes_caeruleus.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Cynara_cardunculus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Cynodon_dactylon.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Cynoglossus_semilaevis.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Cyprinus_carpio.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Cystodytes_dellechiajei.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Dactylis_glomerata.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Danio_rerio.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Daphnia_magna.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Daphnia_obtusa.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Daphnia_pulex.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Daphnia_pulicaria.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Dasypus_novemcinctus.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Daubentonia_madagascariensis.pdf': {'references': [],
#                                                              'type': 'application/pdf'},
#  'data/total_range_plots/Daucus_carota.pdf': {'references': [],
#                                               'type': 'application/pdf'},
#  'data/total_range_plots/Dianthus_caryophyllus.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Dicentrarchus_labrax.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_americana.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_ananassae.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_arizonae.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_bipectinata.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_buzzatii.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_kikkawai.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_malerkotliana.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_melanogaster.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_miranda.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_mojavensis.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_navojoa.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_novamexicana.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_parabipectinata.pdf': {'references': [],
#                                                            'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_persimilis.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_pseudoananassae.pdf': {'references': [],
#                                                            'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_pseudoobscura.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_sechellia.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_serrata.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_simulans.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Drosophila_subobscura.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Echinocardium_cordatum.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Echinocardium_mediterraneum.pdf': {'references': [],
#                                                             'type': 'application/pdf'},
#  'data/total_range_plots/Ectocarpus_siliculosus.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Eichhornia_paniculata.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Eimeria_maxima.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Eimeria_tenella.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Elaeis_guineensis.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Elaeis_oleifera.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'data/total_range_plots/Elymus_lanceolatus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Emys_orbicularis.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Epinephelus_aeneus.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Equus_caballus.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Eremochloa_ophiuroides.pdf': {'references': [],
#                                                        'type': 'application/pdf'},
#  'data/total_range_plots/Eriobotrya_japonica.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Eriocheir_sinensis.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Eschrichtius_robustus.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'data/total_range_plots/Esox_lucius.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'data/total_range_plots/Eucalyptus_camaldulensis.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Eucalyptus_grandis.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Eucalyptus_tereticornis.pdf': {'references': [],
#                                                         'type': 'application/pdf'},
#  'data/total_range_plots/Eucalyptus_urophylla.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Eucommia_ulmoides.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Eudyptes_filholi.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Eudyptes_moseleyi.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Eulemur_coronatus.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'data/total_range_plots/Eulemur_mongoz.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Eunicella_verrucosa.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Fagopyrum_esculentum.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Felis_silvestris.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Fenneropenaeus_chinensis.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'data/total_range_plots/Festuca_arundinacea.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Ficedula_albicollis.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Ficedula_hypoleuca.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Fragaria_iinumae.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'data/total_range_plots/Fragaria_vesca.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'data/total_range_plots/Fragaria_xananassa.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
#  'data/total_range_plots/Fusarium_circinatum.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'data/total_range_plots/Fusarium_graminearum.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'data/total_range_plots/Fusarium_oxysporum.pdf': {'references': [],
#                                                    'type': 'application/pdf'},
# ...
#                                          'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                             'notebooks/figures/plot_funs.r'},
#                                            'inputs': {'data/combined_data.tsv',
#                                                       'data/lognorm_fulldata_with_social.Rdata'},
#                                            'outputs': {'notebooks/figures/diversity_popsize.pdf'},
#                                            'references': [],
#                                            'type': None},
#  'notebooks/figures/diversity_popsize.tds': {'references': [], 'type': None},
#  'notebooks/figures/diversity_popsize_averages.pdf': {'references': [],
#                                                       'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize_averages.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                                      'notebooks/figures/plot_funs.r'},
#                                                     'inputs': {'data/main_datasets.Rdata',
#                                                                'data/phyla_diversity_popsize_ols.Rdata'},
#                                                     'outputs': {'notebooks/figures/diversity_popsize_averages.pdf'},
#                                                     'references': [],
#                                                     'type': None},
#  'notebooks/figures/diversity_popsize_full.pdf': {'references': [],
#                                                   'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize_full.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                                  'notebooks/figures/plot_funs.r'},
#                                                 'inputs': {'data/diversity_popsize_chains.Rdata',
#                                                            'data/main_datasets.Rdata'},
#                                                 'outputs': {'notebooks/figures/diversity_popsize_full.pdf'},
#                                                 'references': [],
#                                                 'type': None},
#  'notebooks/figures/diversity_popsize_linear.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize_linear.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                                    'notebooks/figures/plot_funs.r'},
#                                                   'inputs': {'data/main_datasets.Rdata'},
#                                                   'outputs': {'notebooks/figures/diversity_popsize_linear.pdf'},
#                                                   'references': [],
#                                                   'type': None},
#  'notebooks/figures/diversity_popsize_linkedsel.tds': {'references': [],
#                                                        'type': None},
#  'notebooks/figures/diversity_popsize_redlist.pdf': {'references': [],
#                                                      'type': 'application/pdf'},
#  'notebooks/figures/diversity_popsize_redlist.r': {'dependencies': {'notebooks/figures/plot_funs.r'},
#                                                    'inputs': {'data/diversity_popsize_chains.Rdata',
#                                                               'data/main_datasets.Rdata'},
#                                                    'outputs': {'notebooks/figures/diversity_popsize_redlist.pdf'},
#                                                    'references': [],
#                                                    'type': None},
#  'notebooks/figures/diversity_range_bodymass.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'notebooks/figures/diversity_range_bodymass.r': {'dependencies': {'R/utilities.r',
#                                                                    'notebooks/figures/color_scheme.r'},
#                                                   'inputs': {'data/diversity_range_bodymass_chains.Rdata',
#                                                              'data/main_datasets.Rdata'},
#                                                   'outputs': {'notebooks/figures/diversity_range_bodymass.pdf'},
#                                                   'references': [],
#                                                   'type': None},
#  'notebooks/figures/fecundity_body_size.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'notebooks/figures/fecundity_body_size.r': {'dependencies': {'R/utilities.r'},
#                                              'inputs': {'data/body_size_fecundity.Rdata',
#                                                         'data/romiguier_et_al_2014_updated.tsv'},
#                                              'outputs': {'notebooks/figures/fecundity_body_size.pdf'},
#                                              'references': [],
#                                              'type': None},
#  'notebooks/figures/figure_2.pdf': {'references': [],
#                                     'type': 'application/pdf'},
#  'notebooks/figures/figure_3.pdf': {'references': [],
#                                     'type': 'application/pdf'},
#  'notebooks/figures/figure_3.r': {'dependencies': {'R/utilities.r',
#                                                    'notebooks/figures/color_scheme.r'},
#                                   'inputs': {'data/diversity_popsize_chains.Rdata',
#                                              'data/linked_sel_div_changes.Rdata',
#                                              'data/lognorm_popsize_chains.Rdata',
#                                              'data/main_datasets.Rdata'},
#                                   'outputs': {'notebooks/figures/figure_3.pdf'},
#                                   'references': [],
#                                   'type': None},
#  'notebooks/figures/figure_3_alt.pdf': {'references': [],
#                                         'type': 'application/pdf'},
#  'notebooks/figures/figure_3_alt.r': {'dependencies': {'R/utilities.r',
#                                                        'notebooks/figures/color_scheme.r'},
#                                       'inputs': {'data/diversity_popsize_chains.Rdata',
#                                                  'data/linked_sel_div_changes.Rdata',
#                                                  'data/lognorm_popsize_chains.Rdata',
#                                                  'data/main_datasets.Rdata'},
#                                       'outputs': {'notebooks/figures/figure_3_alt.pdf'},
#                                       'references': [],
#                                       'type': None},
#  'notebooks/figures/genome_size_maplength.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'notebooks/figures/genome_size_maplength.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                                 'notebooks/figures/plot_funs.r'},
#                                                'inputs': {'data/combined_data.tsv'},
#                                                'outputs': {'notebooks/figures/genome_size_maplength.pdf'},
#                                                'references': [],
#                                                'type': None},
#  'notebooks/figures/genome_size_popsize.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'notebooks/figures/genome_size_popsize.r': {'dependencies': {'notebooks/figures/color_scheme.r',
#                                                               'notebooks/figures/plot_funs.r'},
#                                              'inputs': {'data/combined_data.tsv'},
#                                              'outputs': {'notebooks/figures/genome_size_popsize.pdf'},
#                                              'references': [],
#                                              'type': None},
#  'notebooks/figures/iucn_redlist_ranges.pdf': {'references': [],
#                                                'type': 'application/pdf'},
#  'notebooks/figures/linked_sel_params.pdf': {'references': [],
#                                              'type': 'application/pdf'},
#  'notebooks/figures/linked_sel_params.r': {'dependencies': {'R/utilities.r',
#                                                             'notebooks/figures/color_scheme.r'},
#                                            'inputs': {'data/shapiro_et_al_2007.tsv',
#                                                       'data/sweep_param_ests.tsv'},
#                                            'outputs': {'notebooks/figures/linked_sel_params.pdf'},
#                                            'references': [],
#                                            'type': None},
#  'notebooks/figures/map_length_body_size.pdf': {'references': [],
#                                                 'type': 'application/pdf'},
#  'notebooks/figures/map_length_body_size.r': {'dependencies': set(),
#                                               'inputs': {'data/body_size_map_length.Rdata',
#                                                          'data/diversity_size_theory.Rdata'},
#                                               'outputs': {'notebooks/figures/map_length_body_size.pdf'},
#                                               'references': [],
#                                               'type': None},
#  'notebooks/figures/map_length_body_size_bayesian.pdf': {'references': [],
#                                                          'type': 'application/pdf'},
#  'notebooks/figures/map_length_body_size_bayesian.r': {'dependencies': {'R/utilities.r'},
#                                                        'inputs': {'data/body_size_map_length_bayesian.Rdata',
#                                                                   'data/diversity_size_theory.Rdata'},
#                                                        'outputs': {'notebooks/figures/map_length_body_size_bayesian.pdf'},
#                                                        'references': [],
#                                                        'type': None},
#  'notebooks/figures/map_length_body_size_nls.pdf': {'references': [],
#                                                     'type': 'application/pdf'},
#  'notebooks/figures/map_length_body_size_supp.r': {'dependencies': set(),
#                                                    'inputs': {'data/body_size_map_length.Rdata'},
#                                                    'outputs': {'notebooks/figures/map_length_body_size_nls.pdf'},
#                                                    'references': [],
#                                                    'type': None},
#  'notebooks/figures/node_heights.pdf': {'references': [],
#                                         'type': 'application/pdf'},
#  'notebooks/figures/node_heights.r': {'dependencies': {'R/node_height.r',
#                                                        'R/utilities.r',
#                                                        'notebooks/figures/color_scheme.r'},
#                                       'inputs': {'data/main_datasets.Rdata',
#                                                  'data/nodeheights.Rdata'},
#                                       'outputs': {'notebooks/figures/node_heights.pdf'},
#                                       'references': [],
#                                       'type': None},
#  'notebooks/figures/plot_funs.r': {'dependencies': set(),
#                                    'inputs': set(),
#                                    'outputs': set(),
#                                    'references': [],
#                                    'type': None},
#  'notebooks/figures/popsize_histogram.tds': {'references': [], 'type': None},
#  'notebooks/figures/popsize_maplen.tds': {'references': [], 'type': None},
#  'notebooks/figures/popsize_maplength.r': {'dependencies': set(),
#                                            'inputs': set(),
#                                            'outputs': {'notebooks/figures/popsize_maplength.r'},
#                                            'references': [],
#                                            'type': None},
#  'notebooks/figures/popsize_tree.r': {'dependencies': {'R/utilities.r',
#                                                        'notebooks/figures/color_scheme.r'},
#                                       'inputs': {'data/biconmap_data.Rdata',
#                                                  'data/main_datasets.Rdata'},
#                                       'outputs': {'notebooks/figures/popsize_tree.pdf'},
#                                       'references': [],
#                                       'type': None},
#  'notebooks/figures/range_categories.pdf': {'references': [],
#                                             'type': 'application/pdf'},
#  'notebooks/figures/range_categories_long.pdf': {'references': [],
#                                                  'type': 'application/pdf'},
#  'notebooks/figures/redlist_ranges.r': {'dependencies': set(),
#                                         'inputs': {'data/redlist_popsizes.tsv'},
#                                         'outputs': {'notebooks/figures/iucn_redlist_ranges.pdf'},
#                                         'references': [],
#                                         'type': None},
#  'notebooks/figures/species_counts.pdf': {'references': [],
#                                           'type': 'application/pdf'},
#  'notebooks/figures/species_counts.r': {'dependencies': {'notebooks/figures/color_scheme.r'},
#                                         'inputs': {'data/species_by_class.tsv'},
#                                         'outputs': {'notebooks/figures/species_counts.pdf'},
#                                         'references': [],
#                                         'type': None},
#  'notebooks/figures/species_ranges.r': {'dependencies': set(),
#                                         'inputs': {'data/combined_data.tsv'},
#                                         'outputs': {'notebooks/figures/range_categories.pdf'},
#                                         'references': [],
#                                         'type': None},
#  'notebooks/figures/species_ranges_long.r': {'dependencies': set(),
#                                              'inputs': {'data/combined_data.tsv'},
#                                              'outputs': {'notebooks/figures/range_categories_long.pdf'},
#                                              'references': [],
#                                              'type': None},
#  'notebooks/main_analysis.Rmd': {'references': [], 'type': None},
#  'notebooks/render_notebook.r': {'dependencies': set(),
#                                  'inputs': set(),
#                                  'outputs': set(),
#                                  'references': [],
#                                  'type': None},
#  'notebooks/stapley_et_al_2017_pcm.Rmd': {'references': [], 'type': None},
#  'stan/phylo_mm_lognormal.stan': {'references': [], 'type': None},
#  'stan/phylo_mm_regression.stan': {'references': [], 'type': None},
#  'stan/phylo_mm_regression_noresid.stan': {'references': [], 'type': None},
#  'stan/phylomm.stan': {'references': [], 'type': None},
#  'stan/pred_popsize.stan': {'references': [], 'type': None},
#  'stan/pred_popsize_missing.stan': {'references': [], 'type': None},
#  'stan/pred_popsize_missing_centered.stan': {'references': [], 'type': None}}
